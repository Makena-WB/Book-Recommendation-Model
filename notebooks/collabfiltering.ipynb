# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

my_books = pd.read_csv("/content/drive/MyDrive/ProjectFiles/liked_book_s.csv")

my_books.columns = my_books.columns.str.strip()

# %%
my_books
# Out:
#     Unnamed: 0  user_id   book_id  rating  \
# 0            0       -1   2517439       5
# 1            1       -1    113576       5
# 2            2       -1     35100       5
# 3            3       -1    228221       5
# 4            5       -1  17662739       5
# 5            6       -1    356824       5
# 6            7       -1  12125412       5
# 7            8       -1    139069       5
# 8           10       -1     76680       5
# 9           11       -1      1898       5
# 10          12       -1   5096865       5
# 11          13       -1    228665       5
# 12          17       -1    437143       5
# 13          18       -1  18949861       5
# 14          19       -1   2913377       5
# 15          20       -1   1215032       5
# 16          21       -1    883438       5
# 17          22       -1   5578108       5
# 18          23       -1    128029       5
# 19          24       -1     77203       5
# 20          25       -1      5439       5
# 21          26       -1   1685995       5
# 22          27       -1   6448772       5
# 23         527       -1   8161140       1
# 24         528       -1     28187       1
# 25         531       -1  25659450       1
# 26         532       -1     82599       1
#
#                                                 title
# 0              The Forever War  (The Forever War, #1)
# 1   The Smartest Guys in the Room: The Amazing Ris...
# 2                               Battle Cry of Freedom
# 3                                 The Mask of Command
# 4          2001: A Space Odyssey  (Space Odyssey, #1)
# 5   India After Gandhi: The History of the World's...
# 6     The Lady or the Tiger?: and Other Logic Puzzles
# 7           Endurance: Shackleton's Incredible Voyage
# 8                        Foundation  (Foundation, #1)
# 9   Into Thin Air: A Personal Account of the Mount...
# 10                                      In Cold Blood
# 11      The Eye of the World  (The Wheel of Time, #1)
# 12               A Short History of Nearly Everything
# 13                                            Contact
# 14  The Name of the Wind  (The Kingkiller Chronicl...
# 15  The Wise Man's Fear  (The Kingkiller Chronicle...
# 16                                       East of Eden
# 17  From Colony to Superpower: U.S. Foreign Relati...
# 18                           A Thousand Splendid Suns
# 19                                    The Kite Runner
# 20                            Interpreter of Maladies
# 21                                    Dune  (Dune #1)
# 22  Quantum: Einstein, Bohr, and the Great Debate ...
# 23                                       On the Beach
# 24  The Lightning Thief  (Percy Jackson and the Ol...
# 25                                          Arkwright
# 26                                   Rabbits: A Novel

# %%
print(my_books.columns)
print(my_books.dtypes)
# Out:
# Index(['Unnamed: 0', 'user_id', 'book_id', 'rating', 'title'], dtype='object')
# Unnamed: 0     int64
# user_id        int64
# book_id        int64
# rating         int64
# title         object
# dtype: object

# %%
my_books["book_id"] = my_books["book_id"].astype(str)

# %%
# !head /content/drive/MyDrive/ProjectFiles/book_id_map.csv
# Out:
# book_id_csv,book_id
# 0,34684622
# 1,34536488
# 2,34017076
# 3,71730
# 4,30422361
# 5,33503613
# 6,33517540
# 7,34467031
# 8,6383669

# %%
csv_book_mapping = {}

with open("/content/drive/MyDrive/ProjectFiles/book_id_map.csv", "r") as f:
    while True:
        line = f.readline()
        if not line:
            break
        csv_id, book_id = line.strip().split(",")
        csv_book_mapping[csv_id] = book_id

# %%
book_set = set(my_books["book_id"])

# %%
# !head /content/drive/MyDrive/ProjectFiles/goodreads_interactions.csv
# Out:
# user_id,book_id,is_read,rating,is_reviewed
# 0,948,1,5,0
# 0,947,1,5,1
# 0,946,1,5,0
# 0,945,1,5,0
# 0,944,1,5,0
# 0,943,1,5,0
# 0,942,1,5,0
# 0,941,1,5,0
# 0,940,1,5,0

# %%
overlap_users = {}

with open("/content/drive/MyDrive/ProjectFiles/goodreads_interactions.csv", "r") as f:
    while True:
        line = f.readline()
        if not line:
            break

        user_id, csv_id, _, rating, _ = line.split(",")

        book_id = csv_book_mapping.get(csv_id)
        if book_id in book_set:
          if user_id not in overlap_users:
            overlap_users[user_id] = 1
          else:
            overlap_users[user_id] += 1

# %%
len(overlap_users)
# Out:
# 316341

# %%
filtered_overlap_users = set([k for k in overlap_users if overlap_users[k] > my_books.shape[0]/5])

# %%
interactions_list = []

with open("/content/drive/MyDrive/ProjectFiles/goodreads_interactions.csv") as f:
    while True:
        line = f.readline()
        if not line:
            break

        user_id, csv_id, _, rating, _ = line.strip().split(",")
        if user_id in filtered_overlap_users:
          book_id = csv_book_mapping[csv_id]
          interactions_list.append([user_id, book_id, rating])

# %%
len(interactions_list)
# Out:
# 5638701

# %%
interactions_list[0]
# Out:
# ['282', '627206', '4']

# %%
interactions = pd.DataFrame(interactions_list, columns=["user_id", "book_id", "rating"])

# %%
interactions = pd.concat([my_books[["user_id", "book_id", "rating"]], interactions])

# %%
interactions
# Out:
#         user_id   book_id rating
# 0            -1   2517439      5
# 1            -1    113576      5
# 2            -1     35100      5
# 3            -1    228221      5
# 4            -1  17662739      5
# ...         ...       ...    ...
# 5638696  804100    475178      0
# 5638697  804100    186074      0
# 5638698  804100    153008      0
# 5638699  804100     45107      0
# 5638700  804100   1762198      5
#
# [5638728 rows x 3 columns]

# %%
interactions["book_id"] = interactions["book_id"].astype(str)
interactions["user_id"] = interactions["user_id"].astype(str)
interactions["rating"] = pd.to_numeric(interactions["rating"])

# %%
interactions["user_id"].unique()
# Out:
# array(['-1', '282', '874', ..., '442043', '712588', '804100'],
#       dtype=object)

# %%
interactions["user_index"] = interactions["user_id"].astype("category").cat.codes

# %%
len(interactions["user_index"].unique())
# Out:
# 1259

# %%
interactions["book_index"] = interactions["book_id"].astype("category").cat.codes

# %%
len(interactions["book_index"].unique())
# Out:
# 802870

# %%
from scipy.sparse import coo_matrix

ratings_mat_coo = coo_matrix((interactions["rating"], (interactions["user_index"], interactions["book_index"])))

# %%
ratings_mat_coo
# Out:
# <1259x802870 sparse matrix of type '<class 'numpy.int64'>'
# 	with 5638728 stored elements in COOrdinate format>

# %%
ratings_mat = ratings_mat_coo.tocsr()

# %%
interactions[interactions["user_id"] == "-1"]
# Out:
#    user_id   book_id  rating  user_index  book_index
# 0       -1   2517439       5           0      414880
# 1       -1    113576       5           0       38971
# 2       -1     35100       5           0      575858
# 3       -1    228221       5           0      356004
# 4       -1  17662739       5           0      214285
# 5       -1    356824       5           0      581743
# 6       -1  12125412       5           0       59763
# 7       -1    139069       5           0      124430
# 8       -1     76680       5           0      722098
# 9       -1      1898       5           0      276178
# 10      -1   5096865       5           0      625929
# 11      -1    228665       5           0      357774
# 12      -1    437143       5           0      607659
# 13      -1  18949861       5           0      275433
# 14      -1   2913377       5           0      496223
# 15      -1   1215032       5           0       60398
# 16      -1    883438       5           0      767233
# 17      -1   5578108       5           0      637486
# 18      -1    128029       5           0       78172
# 19      -1     77203       5           0      724379
# 20      -1      5439       5           0      633999
# 21      -1   1685995       5           0      188133
# 22      -1   6448772       5           0      671711
# 23      -1   8161140       1           0      742532
# 24      -1     28187       1           0      480322
# 25      -1  25659450       1           0      431105
# 26      -1     82599       1           0      746448

# %%
my_index = 0

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity = cosine_similarity(ratings_mat[my_index,:], ratings_mat).flatten()

# %%
similarity[1]
# Out:
# 0.04579825781910479

# %%
import numpy as np

indices = np.argpartition(similarity, -15)[-15:]

# %%
indices
# Out:
# array([1188,  942,  218,  129,  496,  435, 1208,  795, 1213, 1210, 1143,
#         321,  294,  862,    0])

# %%
similar_users = interactions[interactions["user_index"].isin(indices)].copy()

# %%
similar_users = similar_users[similar_users["user_id"] != "-1"]

# %%
similar_users
# Out:
#         user_id   book_id  rating  user_index  book_index
# 45312      4133      5359       3         942      632143
# 45313      4133  10464963       4         942       13492
# 45314      4133      3858       3         942      593622
# 45315      4133  11827808       4         942       51904
# 45316      4133   7913305       4         942      732465
# ...         ...       ...     ...         ...         ...
# 5638521  712588  32388712       3        1143      543119
# 5638522  712588     16322       5        1143      183365
# 5638523  712588    860543       0        1143      759827
# 5638524  712588    853510       5        1143      756768
# 5638525  712588     13890       4        1143      124251
#
# [4302 rows x 5 columns]

# %%
book_recs = similar_users.groupby("book_id").rating.agg(['count', 'mean'])

# %%
book_recs
# Out:
#           count      mean
# book_id
# 1             6  3.833333
# 100322        1  0.000000
# 100365        1  0.000000
# 10046142      1  0.000000
# 1005          3  0.000000
# ...         ...       ...
# 99561         2  2.500000
# 99610         1  3.000000
# 99664         1  4.000000
# 9969571       3  2.333333
# 99944         1  0.000000
#
# [2856 rows x 2 columns]

# %%
books_titles = pd.read_json("/content/drive/MyDrive/ProjectFiles/book_titles.json")
books_titles["book_id"] = books_titles["book_id"].astype(str)

# %%
book_recs = book_recs.merge(books_titles, how="inner", on="book_id")

# %%
book_recs
# Out:
#        book_id  count      mean  \
# 0            1      6  3.833333
# 1       100322      1  0.000000
# 2       100365      1  0.000000
# 3     10046142      1  0.000000
# 4         1005      3  0.000000
# ...        ...    ...       ...
# 2843     99561      2  2.500000
# 2844     99610      1  3.000000
# 2845     99664      1  4.000000
# 2846   9969571      3  2.333333
# 2847     99944      1  0.000000
#
#                                                   title  ratings  \
# 0     Harry Potter and the Half-Blood Prince (Harry ...  1713866
# 1                              Assata: An Autobiography    11057
# 2                                 The Mote in God's Eye    48736
# 3     Dancing in the Glory of Monsters: The Collapse...     2391
# 4                                   Think and Grow Rich    87634
# ...                                                 ...      ...
# 2843                                 Looking for Alaska   804587
# 2844                                The Best Laid Plans    17434
# 2845                                   The Painted Veil    24606
# 2846                                   Ready Player One   376328
# 2847                                  The Bhagavad Gita    33855
#
#                                                     url  \
# 0     https://www.goodreads.com/book/show/1.Harry_Po...
# 1     https://www.goodreads.com/book/show/100322.Assata
# 2     https://www.goodreads.com/book/show/100365.The...
# 3     https://www.goodreads.com/book/show/10046142-d...
# 4     https://www.goodreads.com/book/show/1005.Think...
# ...                                                 ...
# 2843  https://www.goodreads.com/book/show/99561.Look...
# 2844  https://www.goodreads.com/book/show/99610.The_...
# 2845  https://www.goodreads.com/book/show/99664.The_...
# 2846  https://www.goodreads.com/book/show/9969571-re...
# 2847  https://www.goodreads.com/book/show/99944.The_...
#
#                                               image_url  \
# 0     https://images.gr-assets.com/books/1361039191m...
# 1     https://images.gr-assets.com/books/1328857268m...
# 2     https://images.gr-assets.com/books/1399490037m...
# 3     https://images.gr-assets.com/books/1328757755m...
# 4     https://s.gr-assets.com/assets/nophoto/book/11...
# ...                                                 ...
# 2843  https://images.gr-assets.com/books/1394798630m...
# 2844  https://images.gr-assets.com/books/1353374848m...
# 2845  https://images.gr-assets.com/books/1320421719m...
# 2846  https://images.gr-assets.com/books/1500930947m...
# 2847  https://images.gr-assets.com/books/1383059639m...
#
#                                               mod_title
# 0     harry potter and the halfblood prince harry po...
# 1                               assata an autobiography
# 2                                  the mote in gods eye
# 3     dancing in the glory of monsters the collapse ...
# 4                                   think and grow rich
# ...                                                 ...
# 2843                                 looking for alaska
# 2844                                the best laid plans
# 2845                                   the painted veil
# 2846                                   ready player one
# 2847                                  the bhagavad gita
#
# [2848 rows x 8 columns]

# %%
book_recs["adjusted_count"] = book_recs["count"] * (book_recs["count"] / book_recs["ratings"])

# %%
book_recs["score"] = book_recs["mean"] *book_recs["count"]

# %%
book_recs = book_recs[~book_recs["book_id"].isin(my_books["book_id"])]

# %%
my_books["mod_title"] = my_books["title"].str.replace("[^a-zA-Z0-9 ]", "", regex=True).str.lower()
my_books["mod_title"] = my_books["mod_title"].str.replace("\s+", " ", regex=True)

# %%
book_recs = book_recs[~book_recs["mod_title"].isin(my_books["mod_title"])]

# %%
book_recs = book_recs[book_recs["count"] > 2]

# %%
book_recs = book_recs[book_recs["mean"] > 4]

# %%
top_recs = book_recs.sort_values("score", ascending=False)

# %%
top_recs
# Out:
#       book_id  count      mean  \
# 2260    62291      5  4.800000
# 243    119322      4  4.250000
# 1441  2767793      4  4.250000
# 2558    78983      4  4.250000
# 600    157993      3  4.333333
# 1100    22034      3  4.333333
# 1173  2318271      3  4.333333
# 1906     4381      3  4.333333
#
#                                                title  ratings  \
# 2260  A Storm of Swords (A Song of Ice and Fire, #3)   477834
# 243      The Golden Compass (His Dark Materials, #1)   973154
# 1441                 The Hero of Ages (Mistborn, #3)   149260
# 2558               Kane and Abel (Kane and Abel, #1)    75215
# 600                                The Little Prince   763309
# 1100                                   The Godfather   259150
# 1173                                The Last Lecture   245804
# 1906                                  Fahrenheit 451   591506
#
#                                                     url  \
# 2260  https://www.goodreads.com/book/show/62291.A_St...
# 243   https://www.goodreads.com/book/show/119322.The...
# 1441  https://www.goodreads.com/book/show/2767793-th...
# 2558  https://www.goodreads.com/book/show/78983.Kane...
# 600   https://www.goodreads.com/book/show/157993.The...
# 1100  https://www.goodreads.com/book/show/22034.The_...
# 1173  https://www.goodreads.com/book/show/2318271.Th...
# 1906  https://www.goodreads.com/book/show/4381.Fahre...
#
#                                               image_url  \
# 2260  https://images.gr-assets.com/books/1497931121m...
# 243   https://images.gr-assets.com/books/1505766203m...
# 1441  https://images.gr-assets.com/books/1480717763m...
# 2558  https://s.gr-assets.com/assets/nophoto/book/11...
# 600   https://images.gr-assets.com/books/1367545443m...
# 1100  https://images.gr-assets.com/books/1394988109m...
# 1173  https://images.gr-assets.com/books/1388075896m...
# 1906  https://images.gr-assets.com/books/1351643740m...
#
#                                        mod_title  adjusted_count  score
# 2260  a storm of swords a song of ice and fire 3        0.000052   24.0
# 243      the golden compass his dark materials 1        0.000016   17.0
# 1441                 the hero of ages mistborn 3        0.000107   17.0
# 2558               kane and abel kane and abel 1        0.000213   17.0
# 600                            the little prince        0.000012   13.0
# 1100                               the godfather        0.000035   13.0
# 1173                            the last lecture        0.000037   13.0
# 1906                              fahrenheit 451        0.000015   13.0

# %%
def make_clickable(val):
     return '<a target="_blank" href="{}">Goodreads</a>'.format(val)

def show_image(val):
     return '<img src="{}" width=50></img>'.format(val)

# %%
top_recs.style.format({'url': make_clickable, 'image_url': show_image})
# Out:
# <style type="text/css">
# </style>
# <table id="T_160d1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_160d1_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_160d1_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_160d1_level0_col2" class="col_heading level0 col2" >mean</th>
#       <th id="T_160d1_level0_col3" class="col_heading level0 col3" >title</th>
#       <th id="T_160d1_level0_col4" class="col_heading level0 col4" >ratings</th>
#       <th id="T_160d1_level0_col5" class="col_heading level0 col5" >url</th>
#       <th id="T_160d1_level0_col6" class="col_heading level0 col6" >image_url</th>
#       <th id="T_160d1_level0_col7" class="col_heading level0 col7" >mod_title</th>
#       <th id="T_160d1_level0_col8" class="col_heading level0 col8" >adjusted_count</th>
#       <th id="T_160d1_level0_col9" class="col_heading level0 col9" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_160d1_level0_row0" class="row_heading level0 row0" >2260</th>
#       <td id="T_160d1_row0_col0" class="data row0 col0" >62291</td>
#       <td id="T_160d1_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_160d1_row0_col2" class="data row0 col2" >4.800000</td>
#       <td id="T_160d1_row0_col3" class="data row0 col3" >A Storm of Swords (A Song of Ice and Fire, #3)</td>
#       <td id="T_160d1_row0_col4" class="data row0 col4" >477834</td>
#       <td id="T_160d1_row0_col5" class="data row0 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/62291.A_Storm_of_Swords">Goodreads</a></td>
#       <td id="T_160d1_row0_col6" class="data row0 col6" ><img src="https://images.gr-assets.com/books/1497931121m/62291.jpg" width=50></img></td>
#       <td id="T_160d1_row0_col7" class="data row0 col7" >a storm of swords a song of ice and fire 3</td>
#       <td id="T_160d1_row0_col8" class="data row0 col8" >0.000052</td>
#       <td id="T_160d1_row0_col9" class="data row0 col9" >24.000000</td>
#     </tr>
#     <tr>
#       <th id="T_160d1_level0_row1" class="row_heading level0 row1" >243</th>
#       <td id="T_160d1_row1_col0" class="data row1 col0" >119322</td>
#       <td id="T_160d1_row1_col1" class="data row1 col1" >4</td>
#       <td id="T_160d1_row1_col2" class="data row1 col2" >4.250000</td>
#       <td id="T_160d1_row1_col3" class="data row1 col3" >The Golden Compass (His Dark Materials, #1)</td>
#       <td id="T_160d1_row1_col4" class="data row1 col4" >973154</td>
#       <td id="T_160d1_row1_col5" class="data row1 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/119322.The_Golden_Compass">Goodreads</a></td>
#       <td id="T_160d1_row1_col6" class="data row1 col6" ><img src="https://images.gr-assets.com/books/1505766203m/119322.jpg" width=50></img></td>
#       <td id="T_160d1_row1_col7" class="data row1 col7" >the golden compass his dark materials 1</td>
#       <td id="T_160d1_row1_col8" class="data row1 col8" >0.000016</td>
#       <td id="T_160d1_row1_col9" class="data row1 col9" >17.000000</td>
#     </tr>
#     <tr>
#       <th id="T_160d1_level0_row2" class="row_heading level0 row2" >1441</th>
#       <td id="T_160d1_row2_col0" class="data row2 col0" >2767793</td>
#       <td id="T_160d1_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_160d1_row2_col2" class="data row2 col2" >4.250000</td>
#       <td id="T_160d1_row2_col3" class="data row2 col3" >The Hero of Ages (Mistborn, #3)</td>
#       <td id="T_160d1_row2_col4" class="data row2 col4" >149260</td>
#       <td id="T_160d1_row2_col5" class="data row2 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/2767793-the-hero-of-ages">Goodreads</a></td>
#       <td id="T_160d1_row2_col6" class="data row2 col6" ><img src="https://images.gr-assets.com/books/1480717763m/2767793.jpg" width=50></img></td>
#       <td id="T_160d1_row2_col7" class="data row2 col7" >the hero of ages mistborn 3</td>
#       <td id="T_160d1_row2_col8" class="data row2 col8" >0.000107</td>
#       <td id="T_160d1_row2_col9" class="data row2 col9" >17.000000</td>
#     </tr>
#     <tr>
#       <th id="T_160d1_level0_row3" class="row_heading level0 row3" >2558</th>
#       <td id="T_160d1_row3_col0" class="data row3 col0" >78983</td>
#       <td id="T_160d1_row3_col1" class="data row3 col1" >4</td>
#       <td id="T_160d1_row3_col2" class="data row3 col2" >4.250000</td>
#       <td id="T_160d1_row3_col3" class="data row3 col3" >Kane and Abel (Kane and Abel, #1)</td>
#       <td id="T_160d1_row3_col4" class="data row3 col4" >75215</td>
#       <td id="T_160d1_row3_col5" class="data row3 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/78983.Kane_and_Abel">Goodreads</a></td>
#       <td id="T_160d1_row3_col6" class="data row3 col6" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></td>
#       <td id="T_160d1_row3_col7" class="data row3 col7" >kane and abel kane and abel 1</td>
#       <td id="T_160d1_row3_col8" class="data row3 col8" >0.000213</td>
#       <td id="T_160d1_row3_col9" class="data row3 col9" >17.000000</td>
#     </tr>
#     <tr>
#       <th id="T_160d1_level0_row4" class="row_heading level0 row4" >600</th>
#       <td id="T_160d1_row4_col0" class="data row4 col0" >157993</td>
#       <td id="T_160d1_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_160d1_row4_col2" class="data row4 col2" >4.333333</td>
#       <td id="T_160d1_row4_col3" class="data row4 col3" >The Little Prince</td>
#       <td id="T_160d1_row4_col4" class="data row4 col4" >763309</td>
#       <td id="T_160d1_row4_col5" class="data row4 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/157993.The_Little_Prince">Goodreads</a></td>
#       <td id="T_160d1_row4_col6" class="data row4 col6" ><img src="https://images.gr-assets.com/books/1367545443m/157993.jpg" width=50></img></td>
#       <td id="T_160d1_row4_col7" class="data row4 col7" >the little prince</td>
#       <td id="T_160d1_row4_col8" class="data row4 col8" >0.000012</td>
#       <td id="T_160d1_row4_col9" class="data row4 col9" >13.000000</td>
#     </tr>
#     <tr>
#       <th id="T_160d1_level0_row5" class="row_heading level0 row5" >1100</th>
#       <td id="T_160d1_row5_col0" class="data row5 col0" >22034</td>
#       <td id="T_160d1_row5_col1" class="data row5 col1" >3</td>
#       <td id="T_160d1_row5_col2" class="data row5 col2" >4.333333</td>
#       <td id="T_160d1_row5_col3" class="data row5 col3" >The Godfather</td>
#       <td id="T_160d1_row5_col4" class="data row5 col4" >259150</td>
#       <td id="T_160d1_row5_col5" class="data row5 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/22034.The_Godfather">Goodreads</a></td>
#       <td id="T_160d1_row5_col6" class="data row5 col6" ><img src="https://images.gr-assets.com/books/1394988109m/22034.jpg" width=50></img></td>
#       <td id="T_160d1_row5_col7" class="data row5 col7" >the godfather</td>
#       <td id="T_160d1_row5_col8" class="data row5 col8" >0.000035</td>
#       <td id="T_160d1_row5_col9" class="data row5 col9" >13.000000</td>
#     </tr>
#     <tr>
#       <th id="T_160d1_level0_row6" class="row_heading level0 row6" >1173</th>
#       <td id="T_160d1_row6_col0" class="data row6 col0" >2318271</td>
#       <td id="T_160d1_row6_col1" class="data row6 col1" >3</td>
#       <td id="T_160d1_row6_col2" class="data row6 col2" >4.333333</td>
#       <td id="T_160d1_row6_col3" class="data row6 col3" >The Last Lecture</td>
#       <td id="T_160d1_row6_col4" class="data row6 col4" >245804</td>
#       <td id="T_160d1_row6_col5" class="data row6 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/2318271.The_Last_Lecture">Goodreads</a></td>
#       <td id="T_160d1_row6_col6" class="data row6 col6" ><img src="https://images.gr-assets.com/books/1388075896m/2318271.jpg" width=50></img></td>
#       <td id="T_160d1_row6_col7" class="data row6 col7" >the last lecture</td>
#       <td id="T_160d1_row6_col8" class="data row6 col8" >0.000037</td>
#       <td id="T_160d1_row6_col9" class="data row6 col9" >13.000000
